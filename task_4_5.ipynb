# %% [markdown]
# # Task 4.5
#
#
# Implemenation of Lax-Wendroff scheme
#
#
# Todo: Conjecture a simple condition on the initial profile for a shock to develop in finite time.
#
# As long as it is not "streng monoton steigend" the function should collapse at a point.

# %%
from src.simulation import Simulation
from src.opt_inital_distr import initial_sin, initial_spike, initial_uniform, initial_normal
from src.config import Config 
# used to update module

# %%
config_t2 = Config()
config_t2.test_stability()
sim = Simulation(initial_uniform, config_t2)
sim.run_hopf()
# Out:
# Numerical Stability analysis:
# c * dt / dx <= 1 (perfect for = 1)
# c=1
# dx=0.001
# dt=0.001
# c * dt / dx = 1.00e+00

# %%
sim.plot()
# Out:
# /usr/local/lib/python3.11/site-packages/numpy/linalg/linalg.py:2582: RuntimeWarning: overflow encountered in multiply
#   s = (x.conj() * x).real

# %%
sim.plot_interactive(t_i_steps=5)
# Out:
# interactive(children=(IntSlider(value=500, description='t', max=1001, step=5), Output()), _dom_classes=('widge…
