# %% [markdown]
# # Task 4.2
#
# Implemenation of Lax-Wendroff scheme

# %%
from src.simulation import Simulation
from src.opt_inital_distr import initial_sin, initial_spike, initial_uniform
from src.config import Config

# %%
config_t2 = Config()
config_t2.test_stability()
sim = Simulation(initial_sin, config_t2)
sim.run()
# Out:
# Numerical Stability analysis:
# c * dt / dx <= 1 (perfect for = 1)
# c=1
# dx=0.001
# dt=0.001
# c * dt / dx = 1.00e+00

# %%
sim.plot()

# %%
sim.plot_interactive(t_i_steps=10)
# Out:
# interactive(children=(IntSlider(value=500, description='t', max=1001, step=10), Output()), _dom_classes=('widg…

# %%
sim.calc_analytical()

# %%
# plot a point of time 
sim.plot_interactive(diff=False,t_i_steps=10)
# Out:
# interactive(children=(IntSlider(value=500, description='t', max=1001, step=10), Output()), _dom_classes=('widg…

# %%
# plot a point of time 
sim.plot_interactive(diff=True,t_i_steps=10)
# Out:
# interactive(children=(IntSlider(value=500, description='t', max=1001, step=10), Output()), _dom_classes=('widg…
