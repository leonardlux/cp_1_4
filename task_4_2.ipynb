# %% [markdown]
# # Task 4.2
#
# Implemenation of Lax-Wendroff scheme

# %%
from src.simulation import Simulation
from src.opt_inital_distr import initial_sin, inital_spike

# %%
sim = Simulation(inital_spike)
sim.run()

# %%
sim.plot()

# %%
# plot a point of time 
sim.plot_interactive()
# Out:
# interactive(children=(IntSlider(value=1000, description='t', max=2001, step=100), Output()), _dom_classes=('wi…
